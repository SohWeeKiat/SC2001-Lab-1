# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sb

# %%
dataset = pd.read_csv("MergeInsertion.csv")
dataset.shape
# Out:
# (250, 3)

# %%
dataset.head(n=15)
# Out:
#         Size  S     Time
# 0       1000  0      705
# 1      10000  0     2680
# 2     100000  0    25645
# 3    1000000  0   245161
# 4   10000000  0  2416391
# 5       1000  1     1081
# 6      10000  1     2149
# 7     100000  1    20655
# 8    1000000  1   175068
# 9   10000000  1  1829905
# 10      1000  2      862
# 11     10000  2     2506
# 12    100000  2    15802
# 13   1000000  2   163234
# 14  10000000  2  1569726

# %%
def sizeAgainstTime(s):
    sWithTime = dataset[dataset["Size"] == s]
    sWithTime = sWithTime.drop(["Size"], axis = 1)
    sWithTime = sWithTime[1:]
    sb.regplot(x = sWithTime["S"], y = sWithTime["Time"], data=sWithTime, logx = True, ax = axs[i])

# %%
fig, axs = plt.subplots(5, figsize=(10, 30))
for i in range(5):
    sizeAgainstTime(1000*(10**i))

# %%
nWithTime = dataset[dataset["S"] == 10]

# %%
nWithTime = nWithTime.drop(["S"], axis = 1)

# %%
nWithTime
# Out:
#         Size     Time
# 50      1000     1050
# 51     10000     1451
# 52    100000    13298
# 53   1000000   108454
# 54  10000000  1099213

# %%
sb.scatterplot(data = nWithTime, x = "Size", y = "Time")
# Out:
# <AxesSubplot:xlabel='Size', ylabel='Time'>
